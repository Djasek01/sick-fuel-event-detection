# %% [markdown]
# # Analiza, priprema podataka i vizualizacija događaja goriva
#
# U radu se analizira objedinjeni skup podataka fueldatafinal.csv dobiven spajanjem 4 izvorne CSV datoteke. Cilj je pripremiti podatke, vizualno prikazati njihove ključne obrasce i modelirati ciljnu varijablu withdrawlflag.
#
# Poseban naglasak je na dva izazova: debalansu klasa u ciljnoj varijabli i obradi kategoričke varijable contactvalue.

# %% [markdown]
# ## Uvoz biblioteka

# %%
# analiza podataka
import pandas as pd
import numpy as np

# vizualizacija
import seaborn as sns
import matplotlib.pyplot as plt

# priprema i modeliranje
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.naive_bayes import GaussianNB

# evaluacija
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    RocCurveDisplay
)

# %% [markdown]
# ## Učitavanje i objedinjavanje podataka
#
# Podaci su učitani iz 4 odvojene CSV datoteke i spojeni u jedinstveni skup `merged`, koji se zatim sprema kao `fueldatafinal.csv`. Time se osigurava da se u nastavku analize koriste svi dostupni podaci iz sva 4 vremenska segmenta.

# %%
files = [
    "../data/FuelData/2025-12-01-31/f1.csv",
    "../data/FuelData/2026-01-01-31/f2.csv",
    "../data/FuelData/2026-02-01-28/f3.csv",
    "../data/FuelData/2026-03-01-23/f4.csv",
]

dfs = [pd.read_csv(f, sep=";", dtype=str, encoding="utf-8-sig") for f in files]
merged = pd.concat(dfs, ignore_index=True)
merged.to_csv("../data/FuelData/fuel_data_final.csv", sep=";", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Osnovna deskriptivna statistika
#
# Tablica ispod prikazuje osnovne statistike numeričkih varijabli (srednja vrijednost, medijan, min, max, kvartili).
#
# - `fuel_lvl`: prosječna razina goriva pokazuje tipičnu veličinu spremnika i koliko se ona mijenja.
# - `speed`: pokazuje u kojim rasponima se vozila kreću (npr. puno nula znači stajanje).
# - `gps_latitude` i `gps_longitude`: pokazuju geografski raspon kretanja vozila (npr. okvirno područje Hrvatske).

# %%
merged.describe()[['fuel_lvl', 'speed', 'gps_latitude', 'gps_longitude']]
# Out:
#        fuel_lvl    speed gps_latitude gps_longitude
# count   1187100  1187100      1187082       1187082
# unique     1473      107       448159        508877
# top         300        0    45,327702     14,268447
# freq       4826   658175         4020          4020

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187100 entries, 0 to 1187099
# Data columns (total 8 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   obj_id          1187100 non-null  object
#  1   time            1187100 non-null  object
#  2   fuel_lvl        1187100 non-null  object
#  3   withdrawl_flag  1187100 non-null  object
#  4   speed           1187100 non-null  object
#  5   contact_value   1187100 non-null  object
#  6   gps_latitude    1187082 non-null  object
#  7   gps_longitude   1187082 non-null  object
# dtypes: object(8)
# memory usage: 72.5+ MB

# %% [markdown]
# Objedinjeni skup sadrži 1,187,100 redaka i 8 stupaca: objid, time, fuellvl, withdrawlflag, speed, contactvalue, gpslatitude i gpslongitude.

# %% [markdown]
# Svi stupci su inicijalno učitani kao tekstualni, pa je potrebno provesti konverziju tipova prije analize i modeliranja.

# %% [markdown]
# ## Čišćenje i konverzija tipova

# %% [markdown]
# Stupac time pretvara se u datetime format, a numeričke varijable u odgovarajuće numeričke tipove. Time se omogućuje vremenska analiza, izrada novih značajki i modeliranje.

# %%
# Konverzija stupca 'time' u datetime format
merged["time"] = pd.to_datetime(merged["time"], errors="coerce")

# Konverzija koordinata: zamjena zareza točkom i pretvorba u float
merged["gps_latitude"] = pd.to_numeric(
    merged["gps_latitude"].astype(str).str.replace(",", ".", regex=False),
    errors="coerce"
)

merged["gps_longitude"] = pd.to_numeric(
    merged["gps_longitude"].astype(str).str.replace(",", ".", regex=False),
    errors="coerce"
)

merged["fuel_lvl"] = pd.to_numeric(merged["fuel_lvl"], errors="coerce")
merged["withdrawl_flag"] = pd.to_numeric(merged["withdrawl_flag"], errors="coerce")
merged["speed"] = pd.to_numeric(merged["speed"], errors="coerce")

# Provjera tipova podataka i prvih nekoliko redaka
print(merged.dtypes)
display(merged.head())
# Out:
# obj_id                    object
# time              datetime64[ns]
# fuel_lvl                   int64
# withdrawl_flag             int64
# speed                      int64
# contact_value             object
# gps_latitude             float64
# gps_longitude            float64
# dtype: object
#   obj_id                time  fuel_lvl  withdrawl_flag  speed contact_value  \
# 0   2484 2025-12-08 13:39:00       144               0      0             -
# 1   2484 2025-12-08 13:40:00       144               0      0             -
# 2   2484 2025-12-08 13:41:00       144               0     29             -
# 3   2484 2025-12-08 13:42:00       144               0     37             -
# 4   2484 2025-12-08 13:43:00       144               0      3             -
#
#    gps_latitude  gps_longitude
# 0     45.792643      17.001076
# 1     45.792643      17.001076
# 2     45.793414      17.316811
# 3     45.801079      16.994503
# 4     45.802589      16.995177

# %% [markdown]
# ## Provjera kvalitete podataka
#
# Posebna pažnja posvećena je vrijednostima u stupcima contactvalue i withdrawlflag. U skupu se pojavljuje i vrijednost -1 u ciljnoj varijabli, što zahtijeva dodatnu interpretaciju tijekom analize i evaluacije modela.

# %% [markdown]
# Varijabla `contactvalue` opisuje stanje kontakta vozila i predstavlja važnu kategoričku značajku. Prije modeliranja potrebno je provjeriti koje se vrijednosti pojavljuju i postoje li nedostajući podaci.

# %%
# Provjera jedinstvenih vrijednosti i njihove učestalosti
print("Jedinstvene vrijednosti u contact_value:")
print(merged['contact_value'].unique())

print("\nBroj pojavljivanja svake vrijednosti:")
print(merged['contact_value'].value_counts())

# Provjera nedostajućih vrijednosti
print("\nBroj null vrijednosti:", merged['contact_value'].isnull().sum())
# Out:
# Jedinstvene vrijednosti u contact_value:
# ['-' 'Neaktivan' 'Aktivan']
#
# Broj pojavljivanja svake vrijednosti:
# contact_value
# Aktivan      668709
# Neaktivan    348891
# -            169500
# Name: count, dtype: int64
#
# Broj null vrijednosti: 0

# %%
display(merged[merged['contact_value'] == 'Neaktivan'].head())
# Out:
#      obj_id                time  fuel_lvl  withdrawl_flag  speed  \
# 2280   7935 2025-12-15 18:49:00       398               0      0
# 2281   7935 2025-12-15 18:50:00       398               0      0
# 2282   7935 2025-12-15 18:51:00       398               0      0
# 2283   7935 2025-12-15 18:52:00       398               0      0
# 2284   7935 2025-12-15 18:53:00       398               0      0
#
#      contact_value  gps_latitude  gps_longitude
# 2280     Neaktivan     45.808984      15.869859
# 2281     Neaktivan     45.808984      15.869859
# 2282     Neaktivan     45.808984      15.869859
# 2283     Neaktivan     45.808984      15.869859
# 2284     Neaktivan     45.808984      15.869859

# %%
display(merged[merged['contact_value'] == 'Aktivan'].head())
# Out:
#      obj_id                time  fuel_lvl  withdrawl_flag  speed  \
# 3377  13883 2025-12-01 13:34:00        65               0      0
# 3378  13883 2025-12-01 13:35:00        65               0      0
# 3379  13883 2025-12-01 13:36:00        64               0      0
# 3380  13883 2025-12-01 13:37:00        64               0      0
# 3381  13883 2025-12-01 13:38:00        64               0      0
#
#      contact_value  gps_latitude  gps_longitude
# 3377       Aktivan     46.022352       15.90071
# 3378       Aktivan     46.022355       15.90071
# 3379       Aktivan     46.022355       15.90071
# 3380       Aktivan     46.022355       15.90071
# 3381       Aktivan     46.022355       15.90071

# %%
# Sortiranje po vozilu i vremenu
merged = merged.sort_values(by=["obj_id", "time"])

# Kreiranje prethodne razine goriva i promjene
merged["fuel_lvl_prev"] = merged.groupby("obj_id")["fuel_lvl"].shift(1)
merged["delta_fuel"] = merged["fuel_lvl"] - merged["fuel_lvl_prev"]

merged[["obj_id", "time", "fuel_lvl", "fuel_lvl_prev", "delta_fuel"]].head(10)
# Out:
#         obj_id                time  fuel_lvl  fuel_lvl_prev  delta_fuel
# 267600  101488 2025-12-04 12:47:00       138            NaN         NaN
# 267601  101488 2025-12-04 12:48:00       138          138.0         0.0
# 267602  101488 2025-12-04 12:49:00       139          138.0         1.0
# 267603  101488 2025-12-04 12:50:00       139          139.0         0.0
# 267604  101488 2025-12-04 12:51:00       139          139.0         0.0
# 267605  101488 2025-12-04 12:52:00       139          139.0         0.0
# 267606  101488 2025-12-04 12:53:00       139          139.0         0.0
# 267607  101488 2025-12-04 12:54:00       136          139.0        -3.0
# 267608  101488 2025-12-04 12:55:00       136          136.0         0.0
# 267609  101488 2025-12-04 12:56:00       136          136.0         0.0

# %% [markdown]
# ## Vremenski pogled: kako se gorivo mijenja kroz vrijeme
#
# Na ovom primjeru za jedno vozilo prikazujemo kako se `fuel_lvl` mijenja kroz vrijeme.
#
# - Povišeni i nagli padovi mogu upućivati na punjenje ili pražnjenje spremnika.

# %%
sample_obj = merged[merged['obj_id'] == merged['obj_id'].iloc[0]].sort_values('time').head(200)

plt.figure(figsize=(10, 4))
plt.plot(sample_obj['time'], sample_obj['fuel_lvl'])
plt.title('Promjena razine goriva kroz vrijeme za jedno vozilo')
plt.xlabel('Vrijeme')
plt.ylabel('fuel_lvl')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Stanje kontakta vozila
#
# Ovdje vizualno prikazujemo koliko često je vozilo u stanju `Aktivan`, `Neaktivan` ili `-`.
#
# - `Aktivan` ≈ vozilo je upaljeno.
# - `Neaktivan` ≈ vozilo je ugašeno.
# - `-` ≈ nepoznato ili posebno stanje senzora.

# %%
plt.figure(figsize=(6, 4))
merged['contact_value'].value_counts().plot(kind='bar')
plt.title('Distribucija stanja kontakta (contact_value)')
plt.xlabel('contact_value')
plt.ylabel('Broj opažanja')
plt.show()

# %% [markdown]
# ## Distribucija ciljne varijable
#
# Najprije se analizira raspodjela ciljne varijable `withdrawlflag`. Time se može procijeniti postoji li debalans klasa, što je važno za kasnije modeliranje.

# %%
target_col = "withdrawl_flag"

plt.figure(figsize=(5,4))
sns.countplot(x=target_col, data=merged)
plt.title("Distribucija ciljne varijable withdrawl_flag")
plt.show()

print("Relativni udjeli klasa:")
print(merged[target_col].value_counts(normalize=True))
# Out:
# Relativni udjeli klasa:
# withdrawl_flag
#  0    0.831993
#  1    0.164232
# -1    0.003775
# Name: proportion, dtype: float64

# %% [markdown]
# ### Tumačenje varijable `withdrawl_flag`
#
# Varijabla `withdrawl_flag` predstavlja ciljnu klasu događaja vezanih uz gorivo:
#
# - `0` – uobičajeni (normalni) zapisi bez posebnog događaja povlačenja,
# - `1` – zapisi povezani s naglašenim događajem povlačenja/pražnjenja,
# - `-1` – posebni/sumnjivi ili teško interpretabilni slučajevi (npr. nagli pad goriva uz specifično stanje kontakta i lokacije).
#
# Analiza prosječne razine goriva po klasama pokazuje da se `withdrawl_flag = 1` tipično javlja pri znatno višim razinama goriva nego klasa `0`, dok je klasa `-1` negdje između, ali uz češće prisutne nagle negativne promjene (`delta_fuel`).
# Distribucijski grafovi i boxplotovi potvrđuju da se klase statistički razlikuju, što opravdava korištenje `withdrawl_flag` kao ciljne varijable u modeliranju.

# %% [markdown]
# ## Feature engineering vremenski ovisnih značajki
#
# Za otkrivanje događaja na gorivu važnije je promatrati kako se razina goriva mijenja kroz vrijeme nego samo njezinu trenutnu vrijednost. Zbog toga se uvode dvije nove značajke:
#
# - `fuellvlprev` – prethodna izmjerena razina goriva za isto vozilo
# - `deltafuel` – razlika između trenutačne i prethodne razine goriva
#
# Za ispravan izračun potrebno je podatke sortirati po identifikatoru vozila `objid` i vremenu `time`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

merged['fuel_lvl'] = pd.to_numeric(merged['fuel_lvl'], errors='coerce')
merged['speed'] = pd.to_numeric(merged['speed'], errors='coerce')
merged['withdrawl_flag'] = pd.to_numeric(merged['withdrawl_flag'], errors='coerce')

sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

merged_plot = merged.dropna(subset=['fuel_lvl', 'speed', 'withdrawl_flag']).copy()

merged_plot['fuel_bins'] = pd.cut(merged_plot['fuel_lvl'], bins=10)
sns.countplot(data=merged_plot, x='fuel_bins', ax=axes[0, 0], palette='viridis')
axes[0, 0].set_title('Distribucija razine goriva (fuel_lvl)')
axes[0, 0].tick_params(axis='x', rotation=45)

sns.countplot(data=merged_plot, x='withdrawl_flag', ax=axes[0, 1], palette='Set2')
axes[0, 1].set_title('Distribucija: Istakanje goriva (withdrawl_flag)')

sns.countplot(data=merged_plot, x='contact_value', ax=axes[1, 0], palette='coolwarm')
axes[1, 0].set_title('Distribucija: Stanje kontakta (contact_value)')

merged_plot['speed_bins'] = pd.cut(merged_plot['speed'], bins=10)
sns.countplot(data=merged_plot, x='speed_bins', ax=axes[1, 1], palette='magma')
axes[1, 1].set_title('Distribucija brzine (speed)')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_13716\777875815.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=merged_plot, x='fuel_bins', ax=axes[0, 0], palette='viridis')
# C:\Users\david\AppData\Local\Temp\ipykernel_13716\777875815.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=merged_plot, x='withdrawl_flag', ax=axes[0, 1], palette='Set2')
# C:\Users\david\AppData\Local\Temp\ipykernel_13716\777875815.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
num_cols = ['fuel_lvl', 'withdrawl_flag', 'speed']
for col in num_cols:
    merged[col] = pd.to_numeric(merged[col], errors='coerce')
print(merged[num_cols].describe())
# Out:
#            fuel_lvl  withdrawl_flag         speed
# count  1.187100e+06    1.187100e+06  1.187100e+06
# mean   3.722335e+02    1.604574e-01  2.084240e+01
# std    3.164316e+02    3.771743e-01  3.072252e+01
# min    0.000000e+00   -1.000000e+00  0.000000e+00
# 25%    1.420000e+02    0.000000e+00  0.000000e+00
# 50%    2.680000e+02    0.000000e+00  0.000000e+00
# 75%    4.950000e+02    0.000000e+00  4.000000e+01
# max    1.505000e+03    1.000000e+00  1.270000e+02

# %% [markdown]
# ## Deltafuel i korelacije
#
# Nakon konstruiranja značajke `deltafuel`, prikazuje se njezina distribucija i korelacija numeričkih značajki s ciljnom varijablom. Time se procjenjuje informativnost novih i postojećih značajki.

# %%
# Filtriraj redove s delta_fuel
merged_delta = merged.dropna(subset=["delta_fuel"])

plt.figure(figsize=(6,4))
sns.histplot(merged_delta["delta_fuel"], bins=50, kde=True)
plt.title("Distribucija značajke delta_fuel")
plt.xlabel("delta_fuel")
plt.show()

num_cols = ["fuel_lvl", "fuel_lvl_prev", "delta_fuel", "speed"]
corr = merged_delta[num_cols + [target_col]].corr()

plt.figure(figsize=(6,5))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korelacija numeričkih značajki i ciljne varijable")
plt.show()

# %% [markdown]
# ### Analiza distribucije ciljne varijable

# %%
# Pronalaženje redaka gdje je withdrawl_flag -1
withdrawl_minus_1 = merged[merged['withdrawl_flag'] == -1]

print(f"Broj redaka s withdrawl_flag = -1: {len(withdrawl_minus_1)}")
display(withdrawl_minus_1.head())
# Out:
# Broj redaka s withdrawl_flag = -1: 4481
#        obj_id                time  fuel_lvl  withdrawl_flag  speed  \
# 300150  10160 2026-01-29 08:18:00        50              -1      0
# 300151  10160 2026-01-29 08:19:00        45              -1      0
# 300152  10160 2026-01-29 08:20:00        43              -1      0
# 929055  10160 2026-03-12 08:02:00       200              -1      0
# 929056  10160 2026-03-12 08:03:00       199              -1      0
#
#        contact_value  gps_latitude  gps_longitude  fuel_lvl_prev  delta_fuel
# 300150             -     44.397339      15.127264           50.0         0.0
# 300151             -     44.397339      15.127264           50.0        -5.0
# 300152             -     44.397339      15.127264           45.0        -2.0
# 929055             -     44.397013      15.127026          200.0         0.0
# 929056             -     44.397013      15.127026          200.0        -1.0

# %%
# Analiza korelacije withdrawl_flag-a s promjenom razine goriva
print("Prosječna razina goriva po withdrawl_flag:")
display(merged.groupby('withdrawl_flag')['fuel_lvl'].mean())

# Provjera stanja kontakta za vrijednost -1
print("\nStanje kontakta za withdrawl_flag = -1:")
display(merged[merged['withdrawl_flag'] == -1]['contact_value'].value_counts())
# Out:
# Prosječna razina goriva po withdrawl_flag:
# withdrawl_flag
# -1    310.426021
#  0    346.644882
#  1    503.284971
# Name: fuel_lvl, dtype: float64
# Stanje kontakta za withdrawl_flag = -1:
# contact_value
# Aktivan      1847
# Neaktivan    1481
# -            1153
# Name: count, dtype: int64

# %% [markdown]
# ## Kako izgleda raspodjela goriva i ciljne varijable
#
# Prvi graf (histogram) pokazuje kako je raspoređena razina goriva `fuel_lvl` kroz cijeli skup.
# Drugi graf (boxplot) uspoređuje razine goriva između različitih vrijednosti `withdrawl_flag`.
#
# - Ako vidimo da je za `withdrawl_flag = 1` medijan `fuel_lvl` znatno drugačiji, to sugerira da stanje spremnika za tu klasu ima specifičan obrazac.

# %%
# Distribucija fuel_lvl
plt.figure(figsize=(8, 4))
sns.histplot(merged['fuel_lvl'], bins=50, kde=True)
plt.title('Distribucija razine goriva (fuel_lvl)')
plt.xlabel('fuel_lvl')
plt.ylabel('Broj opažanja')
plt.show()

# Boxplot fuel_lvl po withdrawl_flag
plt.figure(figsize=(8, 4))
sns.boxplot(data=merged, x='withdrawl_flag', y='fuel_lvl')
plt.title('Fuel_lvl po vrijednosti withdrawl_flag')
plt.xlabel('withdrawl_flag')
plt.ylabel('fuel_lvl')
plt.show()

# %% [markdown]
# ## Definiranje značajki i preprocesora
#
# U ovom koraku definiraju se ulazne značajke za modeliranje te se postavlja **preprocessing pipeline** koji automatski obrađuje numeričke i kategoričke varijable.
#
# - Numeričke značajke: `fuel_lvl`, `speed`, `gps_latitude`, `gps_longitude`
# - Kategorička značajka: `contact_value`
#
# Za numeričke značajke primjenjuje se imputacija medijanom i standardizacija, dok se za kategoričku značajku koristi imputacija najčešćom vrijednošću i One-Hot enkodiranje. Svi ovi koraci objedinjeni su u `ColumnTransformer` objektu `preprocessor`, koji se kasnije koristi unutar modelskih pipelineova (Naivni Bayes, Random Forest, XGBoost).
#
# Ovaj dio izravno pokriva:
# - obradu nedostajućih vrijednosti
# - skaliranje numeričkih varijabli
# - enkodiranje kategoričke varijable `contact_value` (One-Hot Encoding)

# %%
# Definiranje značajki
numerical_features = ['fuel_lvl', 'speed', 'gps_latitude', 'gps_longitude',
                       'fuel_lvl_prev', 'delta_fuel']
categorical_features = ['contact_value']

# Pipeline za numeričke značajke: Imputacija medijanom + Standardizacija
num_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Pipeline za kategoričke značajke: Imputacija najčešćom vrijednošću + One-Hot Encoding
cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Spajanje u ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, numerical_features),
        ('cat', cat_transformer, categorical_features)
    ]
)

# Prikaz preprocesora
print("Preprocessing pipeline je definiran.")
display(preprocessor)
# Out:
# Preprocessing pipeline je definiran.
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['fuel_lvl', 'speed', 'gps_latitude',
#                                   'gps_longitude', 'fuel_lvl_prev',
#                                   'delta_fuel']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1187100 entries, 267600 to 928979
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   obj_id          1187100 non-null  object
#  1   time            1187100 non-null  datetime64[ns]
#  2   fuel_lvl        1187100 non-null  int64
#  3   withdrawl_flag  1187100 non-null  int64
#  4   speed           1187100 non-null  int64
#  5   contact_value   1187100 non-null  object
#  6   gps_latitude    1187082 non-null  float64
#  7   gps_longitude   1187082 non-null  float64
#  8   fuel_lvl_prev   1185897 non-null  float64
#  9   delta_fuel      1185897 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 99.6+ MB

# %% [markdown]
# ## Definiranje ulaznih značajki i ciljne varijable
#
# U ovom koraku jasno se razdvajaju ulazne značajke (X) i ciljna varijabla (y) za klasifikacije.
# Iz skupa podataka uklanjaju se stupci `withdrawl_flag`, `time` i `obj_id` iz značajki, pri čemu je `withdrawl_flag` definirana kao ciljna varijabla koju modeli trebaju predvidjeti.
#
# Takva postavka znači:
# - `X` sadrži samo relevantne opisne značajke (razina goriva, brzina, GPS koordinate, stanje kontakta),
# - `y` predstavlja klasu događaja (`withdrawl_flag`) koju želimo modelirati.
#
# ## Podjela na trening i test skup
#
# Podaci se zatim dijele na trening (70 %) i test skup (30 %) uz korištenje parametra `stratify=y`.
# Stratifikacija osigurava da raspodjela klasa u trening i test skupu ostane slična kao u originalnom skupu, što je posebno važno zbog **debalansa klasa** u ciljnoj varijabli.

# %%
# Definiranje značajki (X) i ciljne varijable (y)
X = merged.drop(columns=['withdrawl_flag', 'time', 'obj_id'])
y = merged['withdrawl_flag']

# Podjela na trening i test skup (70/30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42, stratify=y)

print(f"Veličina skupa za treniranje: {X_train.shape[0]} redaka")
print(f"Veličina skupa za testiranje: {X_test.shape[0]} redaka")
# Out:
# Veličina skupa za treniranje: 830970 redaka
# Veličina skupa za testiranje: 356130 redaka

# %% [markdown]
# ## Uzorkovanje podataka za modeliranje
#
# Zbog vrlo velikog skupa podataka, u ovom koraku se nasumično izdvaja uzorak od 200 000 zapisa (`merged_sample_200`) kako bi treniranje modela bilo računski izvedivo.
# Na tom uzorku ponovno se definiraju ulazne značajke (`X_s2`) i ciljna varijabla (`y_s2`), pri čemu se, kao i ranije, iz značajki uklanjaju stupci `withdrawl_flag`, `time` i `obj_id`.
#
# Podaci iz uzorka zatim se dijele na trening i test skup (70/30) uz stratifikaciju po `y_s2`, kako bi se zadržala ista struktura klasa i u manjem skupu.
# Time i dalje poštuješ zahtjev zadatka vezan uz **debalans klasa**, ali u okvirima skupa koji je dovoljno mali za brže eksperimente s modelima.
#
# ## Naivni Bayes – prvi model predviđanja
#
# Na uzorku definira se i trenira Naivni Bayes model koristeći već ranije definirani `preprocessor`:
#
# - `preprocessor` automatski:
#   - imputira nedostajuće vrijednosti,
#   - skalira numeričke značajke,
#   - One-Hot enkodira kategoričku varijablu `contact_value`.
# - `GaussianNB` je klasifikator koji modelira ciljnu varijablu `withdrawl_flag`.
#
# Nakon treniranja modela, na test skupu se izračunavaju sljedeće metrike:
# - točnost (Accuracy),
# - ponderirana preciznost (Precision),
# - ponderirani odziv (Recall),
# - ponderirani F1-score,
# - višeklasni ROC AUC (strategija `ovr`).

# %%
# Uzorkovanje 200,000 zapisa
merged_sample_200 = merged.sample(n=200000, random_state=42)
X_s2 = merged_sample_200.drop(columns=['withdrawl_flag', 'time', 'obj_id'])
y_s2 = merged_sample_200['withdrawl_flag']

# Podjela na trening i test (70/30)
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_s2, y_s2, test_size=0.30, random_state=42, stratify=y_s2)

# Definiranje i treniranje modela
nb_pipeline_200 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', GaussianNB())
])

nb_pipeline_200.fit(X_train_2, y_train_2)

# Predviđanje i evaluacija
y_pred_200 = nb_pipeline_200.predict(X_test_2)
y_proba_200 = nb_pipeline_200.predict_proba(X_test_2)

# Izračun metrika
accuracy = accuracy_score(y_test_2, y_pred_200)
precision = precision_score(y_test_2, y_pred_200, average='weighted', zero_division=0)
recall = recall_score(y_test_2, y_pred_200, average='weighted')
f1 = f1_score(y_test_2, y_pred_200, average='weighted')
roc_auc = roc_auc_score(y_test_2, y_proba_200, multi_class='ovr')

# Prikaz rezultata u traženom formatu
print("--- Rezultati Naivnog Bayesa ---")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-score:  {f1:.4f}")
print(f"ROC AUC:   {roc_auc:.4f}")
print("\nClassification Report:")
print(classification_report(y_test_2, y_pred_200))
# Out:
# --- Rezultati Naivnog Bayesa ---
# Accuracy:  0.7203
# Precision: 0.8090
# Recall:    0.7203
# F1-score:  0.7492
# ROC AUC:   0.7613
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       220
#            0       0.91      0.74      0.82     49912
#            1       0.32      0.64      0.43      9868
#
#     accuracy                           0.72     60000
#    macro avg       0.41      0.46      0.42     60000
# weighted avg       0.81      0.72      0.75     60000

# %% [markdown]
# ## Vizualizacija matrice zabune za Naivni Bayes
#
# Kako bi se detaljnije razumjele pogreške modela Naivnog Bayesa na uzorku od 200 000 zapisa, ovdje se računa i prikazuje **matrica zabune** (`confusion_matrix`).
#
# Dobivena matrica zabune prikazuje:
# - osi prikazuju stvarne i predviđene klase,
# - vrijednosti u ćelijama pokazuju broj ispravno i pogrešno razvrstanih primjera za svaku kombinaciju klasa.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Definiranje oznaka klasa na temelju y_test_2
labels = sorted(y_test_2.unique())

# Izračun matrice zabune
cm_nb_200 = confusion_matrix(y_test_2, y_pred_200, labels=labels)

# Vizualizacija
plt.figure(figsize=(8, 6))
sns.heatmap(cm_nb_200, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels)
plt.title('Matrica zabune: Naivni Bayes (200k uzorak)')
plt.xlabel('Predviđena klasa')
plt.ylabel('Stvarna klasa')
plt.show()

# %% [markdown]
# ## Random Forest kao dodatni model predviđanja
#
# U ovom koraku uvodi se **Random Forest** kao dodatni model predviđanja na istom uzorku od 200 000 zapisa koji je korišten za Naivni Bayes.
# Model se definira kroz `rf_pipeline_200`, koji ponovno koristi isti `preprocessor` (imputacija, skaliranje numeričkih značajki, One-Hot enkodiranje `contact_value`), a kao klasifikator koristi `RandomForestClassifier` sa 100 stabala, fiksiranim `random_state=50` i paralelnim izvođenjem (`n_jobs=-1`).
#
# Nakon treniranja na `X_train_2` i `y_train_2`, model se evaluira na `X_test_2` i `y_test_2` uz izračun istih metrika kao za Naivni Bayes:
# - Accuracy
# - ponderirana Precision
# - ponderirani Recall
# - ponderirani F1-score
# - višeklasni ROC AUC (`multi_class='ovr'`)
#
# Ispisuje se i detaljan `classification_report`, što omogućava izravnu usporedbu performansi Random Foresta s Naivnim Bayesom po svim klasama ciljne varijable.
#
# ## Vizualizacija matrice zabune za Random Forest
#
# Za Random Forest računa se i prikazuje **matrica zabune** (`cm_rf_200`) koristeći iste oznake klasa (`labels`) kao kod Naivnog Bayesa.
# Vizualizacija putem `seaborn.heatmap` (zeleno obojena skala) omogućuje pregled gdje Random Forest postiže bolje ili lošije razvrstavanje u odnosu na "Naivni Bayes", posebno u kontekstu debalansa klasa.

# %%
from sklearn.ensemble import RandomForestClassifier

# Definiranje i treniranje Random Forest modela na 200k uzorku
rf_pipeline_200 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=50, n_jobs=-1))
])

rf_pipeline_200.fit(X_train_2, y_train_2)

# Predviđanje i evaluacija
y_pred_rf_200 = rf_pipeline_200.predict(X_test_2)
y_proba_rf_200 = rf_pipeline_200.predict_proba(X_test_2)

# Izračun metrika
accuracy_rf = accuracy_score(y_test_2, y_pred_rf_200)
precision_rf = precision_score(y_test_2, y_pred_rf_200, average='weighted', zero_division=0)
recall_rf = recall_score(y_test_2, y_pred_rf_200, average='weighted')
f1_rf = f1_score(y_test_2, y_pred_rf_200, average='weighted')
roc_auc_rf = roc_auc_score(y_test_2, y_proba_rf_200, multi_class='ovr')

# Prikaz rezultata
print("--- Rezultati Random Foresta ---")
print(f"Accuracy:  {accuracy_rf:.4f}")
print(f"Precision: {precision_rf:.4f}")
print(f"Recall:    {recall_rf:.4f}")
print(f"F1-score:  {f1_rf:.4f}")
print(f"ROC AUC:   {roc_auc_rf:.4f}")
print("\nClassification Report:")
print(classification_report(y_test_2, y_pred_rf_200))

# Matrica zabune
plt.figure(figsize=(8, 6))
cm_rf_200 = confusion_matrix(y_test_2, y_pred_rf_200, labels=labels)
sns.heatmap(cm_rf_200, annot=True, fmt='d', cmap='Greens',
            xticklabels=labels, yticklabels=labels)
plt.title('Matrica zabune: Random Forest (200k uzorak)')
plt.xlabel('Predviđena klasa')
plt.ylabel('Stvarna klasa')
plt.show()
# Out:
# --- Rezultati Random Foresta ---
# Accuracy:  0.9437
# Precision: 0.9419
# Recall:    0.9437
# F1-score:  0.9406
# ROC AUC:   0.9228
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.71      0.18      0.28       220
#            0       0.95      0.99      0.97     49912
#            1       0.91      0.75      0.82      9868
#
#     accuracy                           0.94     60000
#    macro avg       0.86      0.64      0.69     60000
# weighted avg       0.94      0.94      0.94     60000

# %% [markdown]
# ## XGBoost kao napredni model predviđanja
#
# U ovom dijelu uvodi se **XGBoost** kao treći, napredni model predviđanja na istom uzorku od 200 000 zapisa.
# Budući da XGBoost očekuje da oznake klasa budu kodirane cjelobrojnim vrijednostima koje počinju od 0, ciljana varijabla `y_train_2` i `y_test_2` najprije se transformiraju pomoću `LabelEncoder`a (`y_train_xgb_200`, `y_test_xgb_200`).
#
# Na taj način XGBoost dobiva na ulazu već pripremljene, standardizirane i enkodirane značajke, jednako kao i Naivni Bayes te Random Forest.
#
# Nakon treniranja, izračunavaju se iste metrike kao za ostale modele:
# - Accuracy
# - ponderirana Precision
# - ponderirani Recall
# - ponderirani F1-score
# - višeklasni ROC AUC (`multi_class='ovr'`)
#
# ## Vizualizacija matrice zabune za XGBoost
#
# Za XGBoost se računa i prikazuje **matrica zabune** (`cm_xgb_200`), pri čemu se:
# - koristi ista struktura (stvarna vs. predviđena klasa),
# - oznake na osima (`xticklabels` i `yticklabels`) postavljaju na originalne klase pomoću `le_200.classes_`.
#
# Vizualizacija putem `seaborn.heatmap` (narančasta skala) omogućuje pregled raspodjele točnih i pogrešnih predikcija XGBoosta te usporedbu s matricama zabune za Naivni Bayes i Random Forest.

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# XGBoost zahtijeva da klase počinju od 0 (npr. 0, 1, 2)
le_200 = LabelEncoder()
y_train_xgb_200 = le_200.fit_transform(y_train_2)
y_test_xgb_200 = le_200.transform(y_test_2)

# Kreiranje XGBoost modela u pipelineu
xgb_pipeline_200 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', XGBClassifier(n_estimators=100, random_state=50, use_label_encoder=False, eval_metric='mlogloss'))
])

# Treniranje
xgb_pipeline_200.fit(X_train_2, y_train_xgb_200)

# Predviđanje i vjerojatnosti
y_pred_xgb_200 = xgb_pipeline_200.predict(X_test_2)
y_proba_xgb_200 = xgb_pipeline_200.predict_proba(X_test_2)

# Izračun metrika
accuracy_xgb = accuracy_score(y_test_xgb_200, y_pred_xgb_200)
precision_xgb = precision_score(y_test_xgb_200, y_pred_xgb_200, average='weighted', zero_division=0)
recall_xgb = recall_score(y_test_xgb_200, y_pred_xgb_200, average='weighted')
f1_xgb = f1_score(y_test_xgb_200, y_pred_xgb_200, average='weighted')
roc_auc_xgb = roc_auc_score(y_test_xgb_200, y_proba_xgb_200, multi_class='ovr')

# Prikaz rezultata
print("--- Rezultati XGBoosta ---")
print(f"Accuracy:  {accuracy_xgb:.4f}")
print(f"Precision: {precision_xgb:.4f}")
print(f"Recall:    {recall_xgb:.4f}")
print(f"F1-score:  {f1_xgb:.4f}")
print(f"ROC AUC:   {roc_auc_xgb:.4f}")
print("\nClassification Report:")
print(classification_report(y_test_xgb_200, y_pred_xgb_200, target_names=[str(c) for c in le_200.classes_]))

# Matrica zabune
plt.figure(figsize=(8, 6))
cm_xgb_200 = confusion_matrix(y_test_xgb_200, y_pred_xgb_200)
sns.heatmap(cm_xgb_200, annot=True, fmt='d', cmap='Oranges',
            xticklabels=le_200.classes_, yticklabels=le_200.classes_)
plt.title('Matrica zabune: XGBoost (200k uzorak)')
plt.xlabel('Predviđena klasa')
plt.ylabel('Stvarna klasa')
plt.show()
# Out:
# c:\Users\david\miniconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [11:56:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# --- Rezultati XGBoosta ---
# Accuracy:  0.9453
# Precision: 0.9445
# Recall:    0.9453
# F1-score:  0.9419
# ROC AUC:   0.9501
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.68      0.24      0.35       220
#            0       0.95      0.99      0.97     49912
#            1       0.94      0.73      0.82      9868
#
#     accuracy                           0.95     60000
#    macro avg       0.85      0.65      0.71     60000
# weighted avg       0.94      0.95      0.94     60000

# %% [markdown]
# Matrice zabune dodatno pokazuju koliko se razlikuju ove klase: dijagonalni elementi predstavljaju točne pogodke po klasi, dok izvan-dijagonalni elementi otkrivaju gdje modeli najviše griješe (npr. kad sumnjive događaje (-1) pogrešno klasificiraju kao normalne (0)).

# %% [markdown]
# ## Usporedna analiza performansi modela
#
# U ovom završnom koraku izrađuje se **sažetak performansi sva tri modela** (Naivni Bayes, Random Forest, XGBoost) u jednoj tablici i vizualizaciji.
# Najprije se numeričke vrijednosti metrika (Accuracy, Precision, Recall, F1-score, ROC AUC) za svaki model spremaju u `DataFrame` `df_comparison`, a zatim se pomoću `melt` transformacije pretvaraju u dugi format (`df_melted`) pogodan za grupirani stupčasti graf.
#
# Pomoću `seaborn.barplot` crta se graf na kojem:
# - X-os predstavlja modele (Naivni Bayes, Random Forest, XGBoost),
# - Y-os predstavlja vrijednosti metrika,
# - boje (hue) razlikuju pojedine metrike (Accuracy, Precision, Recall, F1-score, ROC AUC).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Osiguravanje da su podaci u ispravnom formatu za vizualizaciju
comparison_data = {
    'Model': ['Naivni Bayes', 'Random Forest', 'XGBoost'],
    'Accuracy': [accuracy, accuracy_rf, accuracy_xgb],
    'Precision': [precision, precision_rf, precision_xgb],
    'Recall': [recall, recall_rf, recall_xgb],
    'F1-score': [f1, f1_rf, f1_xgb],
    'ROC AUC': [roc_auc, roc_auc_rf, roc_auc_xgb]
}
df_comparison = pd.DataFrame(comparison_data)
df_melted = df_comparison.melt(id_vars='Model', var_name='Metrika', value_name='Vrijednost')

# Vizualizacija s modelima na X-osi prema vašem kodu
plt.figure(figsize=(14, 8))
sns.barplot(data=df_melted, x='Model', y='Vrijednost', hue='Metrika', palette='magma')

plt.title('Usporedba performansi po modelima (200k uzorak)')
plt.ylim(0, 1.1)
plt.ylabel('Vrijednost metrike')
plt.xlabel('Model')
plt.legend(title='Metrike', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Dodavanje vrijednosti iznad stupaca
for p in plt.gca().patches:
    if p.get_height() > 0:
        plt.gca().annotate(f'{p.get_height():.3f}',
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha = 'center', va = 'center',
                       xytext = (0, 9),
                       textcoords = 'offset points',
                       fontsize=8,
                       rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logistička regresija kao dodatni referentni model
#
# Nakon treniranja na `X_train_2` i `y_train_2`, model se evaluira na `X_test_2` i `y_test_2` uz izračun standardnih metrika:
# - Accuracy
# - ponderirana Precision
# - ponderirani Recall
# - ponderirani F1-score
# - višeklasni ROC AUC (`multi_class='ovr'`)
#
#
# ## Vizualizacija matrice zabune za Logističku regresiju
#
# Za logističku regresiju računa se **matrica zabune** (`cm_lr_200`) koristeći iste oznake klasa (`labels`) kao i kod Naivnog Bayesa i Random Foresta.
# Vizualizacija putem `seaborn.heatmap` (ljubičasta skala) pokazuje kako model raspoređuje pojedine klase (stvarna vs. predviđena), te omogućuje uvid u pogreške logističke regresije.

# %%
from sklearn.linear_model import LogisticRegression

# Definiranje i treniranje modela Logističke regresije u pipelineu
lr_pipeline_200 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000, random_state=50))
])

lr_pipeline_200.fit(X_train_2, y_train_2)

# Predviđanje i vjerojatnosti
y_pred_lr_200 = lr_pipeline_200.predict(X_test_2)
y_proba_lr_200 = lr_pipeline_200.predict_proba(X_test_2)

# Izračun metrika
accuracy_lr = accuracy_score(y_test_2, y_pred_lr_200)
precision_lr = precision_score(y_test_2, y_pred_lr_200, average='weighted', zero_division=0)
recall_lr = recall_score(y_test_2, y_pred_lr_200, average='weighted')
f1_lr = f1_score(y_test_2, y_pred_lr_200, average='weighted')
roc_auc_lr = roc_auc_score(y_test_2, y_proba_lr_200, multi_class='ovr')

# Prikaz rezultata
print("--- Rezultati Logističke regresije ---")
print(f"Accuracy:  {accuracy_lr:.4f}")
print(f"Precision: {precision_lr:.4f}")
print(f"Recall:    {recall_lr:.4f}")
print(f"F1-score:  {f1_lr:.4f}")
print(f"ROC AUC:   {roc_auc_lr:.4f}")
print("\nClassification Report:")
print(classification_report(y_test_2, y_pred_lr_200))

# Matrica zabune
plt.figure(figsize=(8, 6))
cm_lr_200 = confusion_matrix(y_test_2, y_pred_lr_200, labels=labels)
sns.heatmap(cm_lr_200, annot=True, fmt='d', cmap='Purples',
            xticklabels=labels, yticklabels=labels)
plt.title('Matrica zabune: Logistička regresija (200k uzorak)')
plt.xlabel('Predviđena klasa')
plt.ylabel('Stvarna klasa')
plt.show()
# Out:
# --- Rezultati Logističke regresije ---
# Accuracy:  0.9331
# Precision: 0.9335
# Recall:    0.9331
# F1-score:  0.9253
# ROC AUC:   0.8504
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       220
#            0       0.93      1.00      0.96     49912
#            1       0.99      0.62      0.76      9868
#
#     accuracy                           0.93     60000
#    macro avg       0.64      0.54      0.58     60000
# weighted avg       0.93      0.93      0.93     60000
# c:\Users\david\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %% [markdown]
# ### Proširena usporedba performansi svih modela
# U nastavku je prikazana usporedba četiriju testiranih modela: Naivni Bayes, Random Forest, XGBoost i Logistička regresija.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Priprema podataka za usporedbu svih 4 modela
comparison_data_full = {
    "Model": ["Naivni Bayes", "Random Forest", "XGBoost", "Logistička Regresija"],
    "Accuracy": [accuracy, accuracy_rf, accuracy_xgb, accuracy_lr],
    "Precision": [precision, precision_rf, precision_xgb, precision_lr],
    "Recall": [recall, recall_rf, recall_xgb, recall_lr],
    "F1-score": [f1, f1_rf, f1_xgb, f1_lr],
    "ROC AUC": [roc_auc, roc_auc_rf, roc_auc_xgb, roc_auc_lr]
}

df_comparison_full = pd.DataFrame(comparison_data_full)
df_melted_full = df_comparison_full.melt(id_vars="Model", var_name="Metrika", value_name="Vrijednost")

# Vizualizacija
plt.figure(figsize=(16, 8))
sns.barplot(data=df_melted_full, x="Model", y="Vrijednost", hue="Metrika", palette="magma")

plt.title("Sveobuhvatna usporedba performansi modela (200k uzorak)")
plt.ylim(0, 1.2)
plt.ylabel("Vrijednost metrike")
plt.xlabel("Model")
plt.legend(title="Metrike", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Dodavanje oznaka vrijednosti
for p in plt.gca().patches:
    if p.get_height() > 0:
        plt.gca().annotate(f"{p.get_height():.3f}",
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha = "center", va = "center",
                       xytext = (0, 9),
                       textcoords = "offset points",
                       fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Provjera i priprema podataka za ANN

# %%
# Provjera i priprema podataka za ANN

print("Oblik X_train_2:", X_train_2.shape)
print("Oblik X_test_2:", X_test_2.shape)

print("\nRaspodjela klasa u y_train_2:")
print(y_train_2.value_counts())
print("\nRaspodjela klasa u y_test_2:")
print(y_test_2.value_counts())
# Out:
# Oblik X_train_2: (140000, 7)
# Oblik X_test_2: (60000, 7)
#
# Raspodjela klasa u y_train_2:
# withdrawl_flag
#  0    116463
#  1     23025
# -1       512
# Name: count, dtype: int64
#
# Raspodjela klasa u y_test_2:
# withdrawl_flag
#  0    49912
#  1     9868
# -1      220
# Name: count, dtype: int64

# %% [markdown]
# # Skaliranje značajki za neuronsku mrežu

# %%
# Skaliranje i kodiranje značajki za ANN korištenjem postojećeg preprocessor-a

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
import numpy as np
from sklearn.base import clone


# Reproducibilnost
np.random.seed(42)
tf.random.set_seed(42)


# Preprocesiranje ulaznih značajki - zaseban preprocessor samo za ANN
preprocessor_ann = clone(preprocessor)

X_train_2_proc = preprocessor_ann.fit_transform(X_train_2)
X_test_2_proc = preprocessor_ann.transform(X_test_2)

# Ako je izlaz sparse matrica, pretvori u dense zbog TensorFlowa
if hasattr(X_train_2_proc, "toarray"):
    X_train_2_proc = X_train_2_proc.toarray()
if hasattr(X_test_2_proc, "toarray"):
    X_test_2_proc = X_test_2_proc.toarray()

# TensorFlow voli float32
X_train_2_proc = X_train_2_proc.astype(np.float32)
X_test_2_proc = X_test_2_proc.astype(np.float32)

print("Oblik preprocesiranog X_train_2_proc:", X_train_2_proc.shape)
print("Oblik preprocesiranog X_test_2_proc:", X_test_2_proc.shape)
# Out:
# Oblik preprocesiranog X_train_2_proc: (140000, 9)
# Oblik preprocesiranog X_test_2_proc: (60000, 9)

# %% [markdown]
# # Izgradnja i treniranje ANN modela (Keras / TensorFlow)

# %%
# Izgradnja ANN modela (Keras / TensorFlow)

# Enkodiranje klasa (-1, 0, 1 -> 0,1,2)
label_map = {label: idx for idx, label in enumerate(sorted(y_train_2.unique()))}
inverse_label_map = {v: k for k, v in label_map.items()}

y_train_2_enc = y_train_2.map(label_map).values
y_test_2_enc = y_test_2.map(label_map).values

num_classes = len(label_map)

# Class weights zbog debalansa klasa
classes = np.unique(y_train_2_enc)
class_weights_values = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_2_enc
)
class_weights = {int(cls): float(weight) for cls, weight in zip(classes, class_weights_values)}

print("Class weights:", class_weights)

# Definicija mreže
input_dim = X_train_2_proc.shape[1]

model_ann = keras.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.30),

    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.20),

    layers.Dense(32, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

model_ann.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model_ann.summary()
# Out:
# Class weights: {0: 91.14583333333333, 1: 0.4006995068533926, 2: 2.0267824828085415}
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## Treniranje

# %%
# Treniranje ANN modela

early_stop = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=4,
    restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-5
)

history_ann = model_ann.fit(
    X_train_2_proc, y_train_2_enc,
    validation_split=0.2,
    epochs=40,
    batch_size=512,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/40
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5425 - loss: 0.8955 - val_accuracy: 0.5905 - val_loss: 0.8314 - learning_rate: 0.0010
# Epoch 2/40
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5918 - loss: 0.7589 - val_accuracy: 0.5577 - val_loss: 0.7753 - learning_rate: 0.0010
# Epoch 3/40
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6081 - loss: 0.7166 - val_accuracy: 0.6068 - val_loss: 0.7443 - learning_rate: 0.0010
# Epoch 4/40
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6354 - loss: 0.6806 - val_accuracy: 0.6372 - val_loss: 0.7211 - learning_rate: 0.0010
# Epoch 5/40
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6607 - loss: 0.6607 - val_accuracy: 0.6400 - val_loss: 0.7192 - learning_rate: 0.0010
# Epoch 6/40
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6672 - loss: 0.6553 - val_accuracy: 0.6106 - val_loss: 0.7396 - learning_rate: 0.0010
# Epoch 7/40
# ...

# %% [markdown]
# # Evaluacija ANN modela na test skupu

# %%
# Evaluacija ANN modela na test skupu

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    f1_score
)
import seaborn as sns
import matplotlib.pyplot as plt

# Predikcije
y_pred_proba_ann = model_ann.predict(X_test_2_proc)
y_pred_enc_ann = np.argmax(y_pred_proba_ann, axis=1)
y_pred_ann = np.vectorize(inverse_label_map.get)(y_pred_enc_ann)

print("--- Rezultati ANN ---")
print("Accuracy:", accuracy_score(y_test_2, y_pred_ann))
print("F1 (macro):", f1_score(y_test_2, y_pred_ann, average='macro', zero_division=0))
print("\nClassification report:")
print(classification_report(y_test_2, y_pred_ann, zero_division=0))

# Matrica zabune
labels = sorted(label_map.keys())
cm_ann = confusion_matrix(y_test_2, y_pred_ann, labels=labels)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm_ann,
    annot=True,
    fmt='d',
    cmap='Oranges',
    xticklabels=labels,
    yticklabels=labels
)
plt.title("Matrica zabune – ANN (uzorak 200 000)")
plt.xlabel("Predviđena klasa")
plt.ylabel("Stvarna klasa")
plt.show()
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# --- Rezultati ANN ---
# Accuracy: 0.8052666666666667
# F1 (macro): 0.5629830122327969
#
# Classification report:
#               precision    recall  f1-score   support
#
#           -1       0.02      0.70      0.04       220
#            0       0.94      0.82      0.88     49912
#            1       0.84      0.71      0.77      9868
#
#     accuracy                           0.81     60000
#    macro avg       0.60      0.75      0.56     60000
# weighted avg       0.92      0.81      0.86     60000

# %% [markdown]
# # Izračun metrika za ANN u istom formatu

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# weighted metrike - ostaju iste varijable zbog nastavka notebooka
acc_ann = accuracy_score(y_test_2, y_pred_ann)
prec_ann = precision_score(y_test_2, y_pred_ann, average='weighted', zero_division=0)
rec_ann = recall_score(y_test_2, y_pred_ann, average='weighted', zero_division=0)
f1_ann = f1_score(y_test_2, y_pred_ann, average='weighted', zero_division=0)

# dodatne macro metrike - važnije kod debalansa klasa
prec_macro_ann = precision_score(y_test_2, y_pred_ann, average='macro', zero_division=0)
rec_macro_ann = recall_score(y_test_2, y_pred_ann, average='macro', zero_division=0)
f1_macro_ann = f1_score(y_test_2, y_pred_ann, average='macro', zero_division=0)

# ROC AUC za multiklasni problem
roc_auc_ann = roc_auc_score(y_test_2_enc, y_pred_proba_ann, multi_class='ovr')

print("ANN - Accuracy:", acc_ann)
print("ANN - Precision weighted:", prec_ann)
print("ANN - Recall weighted:", rec_ann)
print("ANN - F1-score weighted:", f1_ann)
print("ANN - Precision macro:", prec_macro_ann)
print("ANN - Recall macro:", rec_macro_ann)
print("ANN - F1-score macro:", f1_macro_ann)
print("ANN - ROC AUC:", roc_auc_ann)
# Out:
# ANN - Accuracy: 0.8052666666666667
# ANN - Precision weighted: 0.9243592612694251
# ANN - Recall weighted: 0.8052666666666667
# ANN - F1-score weighted: 0.8593138917895362
# ANN - Precision macro: 0.6019379742341003
# ANN - Recall macro: 0.7468168102821696
# ANN - F1-score macro: 0.5629830122327969
# ANN - ROC AUC: 0.8876532649861227

# %%
comparison_data_full = {
    "Model": [
        "Naivni Bayes",
        "Random Forest",
        "XGBoost",
        "Logistička Regresija",
        "ANN",
    ],
    "Accuracy": [accuracy, accuracy_rf, accuracy_xgb, accuracy_lr, acc_ann],
    "Precision": [precision, precision_rf, precision_xgb, precision_lr, prec_ann],
    "Recall": [recall, recall_rf, recall_xgb, recall_lr, rec_ann],
    "F1-score": [f1, f1_rf, f1_xgb, f1_lr, f1_ann],
    "ROC AUC": [roc_auc, roc_auc_rf, roc_auc_xgb, roc_auc_lr, roc_auc_ann],
}

# %% [markdown]
# ### Rezultat

# %%
df_comparison_full = pd.DataFrame(comparison_data_full)
df_melted_full = df_comparison_full.melt(
    id_vars="Model", var_name="Metrika", value_name="Vrijednost"
)

# %%
plt.figure(figsize=(16, 8))
sns.barplot(data=df_melted_full, x="Model", y="Vrijednost", hue="Metrika", palette="magma")

plt.title("Sveobuhvatna usporedba performansi modela 200k uzorak")
plt.ylim(0, 1.2)
plt.ylabel("Vrijednost metrike")
plt.xlabel("Model")
plt.legend(title="Metrike", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(axis="y", linestyle="--", alpha=0.7)

for p in plt.gca().patches:
    if p.get_height() > 0:
        plt.gca().annotate(
            f"{p.get_height():.3f}",
            (p.get_x() + p.get_width() / 2., p.get_height()),
            ha="center", va="center",
            xytext=(0, 9), textcoords="offset points",
            fontsize=8
        )

plt.tight_layout()
plt.show()
